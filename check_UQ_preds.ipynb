# %%
import os
import pandas as pd

# %%
df = pd.read_csv("/home/macraedc/UQ_results/TTA/OS/model_1/all_predictions.csv", sep=';')

df
# Out:
#     PatientID  OS_2year_censored_true  OS_2year_censored_pred_model_1  \
# 0       59896                     0.0                        0.048767
# 1       79595                     1.0                        0.536435
# 2      263964                     0.0                        0.066172
# 3      345451                     0.0                        0.120244
# 4      585519                     0.0                        0.094312
# ..        ...                     ...                             ...
# 77    9516522                     0.0                        0.200661
# 78    9618642                     0.0                        0.364523
# 79    9735198                     0.0                        0.034731
# 80    9743734                     0.0                        0.033271
# 81    9919987                     1.0                        0.697071
#
#     OS_2year_censored_pred_model_10  OS_2year_censored_pred_model_11  \
# 0                          0.074639                         0.050093
# 1                          0.486934                         0.531816
# 2                          0.073677                         0.065954
# 3                          0.168675                         0.085562
# 4                          0.063427                         0.077634
# ..                              ...                              ...
# 77                         0.195981                         0.230727
# 78                         0.312483                         0.317764
# 79                         0.076736                         0.052602
# 80                         0.023178                         0.063911
# 81                         0.639577                         0.637371
#
#     OS_2year_censored_pred_model_12  OS_2year_censored_pred_model_13  \
# 0                          0.039423                         0.057270
# 1                          0.566707                         0.537152
# 2                          0.069793                         0.069036
# 3                          0.087645                         0.126850
# 4                          0.069088                         0.092668
# ..                              ...                              ...
# 77                         0.234555                         0.248338
# 78                         0.426486                         0.353093
# 79                         0.068885                         0.061861
# 80                         0.052606                         0.056916
# 81                         0.686688                         0.657131
#
#     OS_2year_censored_pred_model_14  OS_2year_censored_pred_model_15  \
# 0                          0.067655                         0.056797
# 1                          0.488891                         0.586583
# 2                          0.108390                         0.111798
# 3                          0.108269                         0.061893
# 4                          0.073440                         0.064166
# ..                              ...                              ...
# 77                         0.168309                         0.171363
# 78                         0.403460                         0.329506
# 79                         0.039491                         0.045015
# 80                         0.040325                         0.033659
# 81                         0.692259                         0.692380
#
#     OS_2year_censored_pred_model_16  ...  OS_2year_censored_pred_model_46  \
# 0                          0.050745  ...                         0.029811
# 1                          0.563026  ...                         0.541176
# 2                          0.079128  ...                         0.079365
# 3                          0.110835  ...                         0.109578
# 4                          0.051380  ...                         0.076221
# ..                              ...  ...                              ...
# 77                         0.228732  ...                         0.212430
# 78                         0.268778  ...                         0.277585
# 79                         0.051894  ...                         0.063442
# 80                         0.045854  ...                         0.052785
# 81                         0.700945  ...                         0.667699
#
#     OS_2year_censored_pred_model_47  OS_2year_censored_pred_model_48  \
# 0                          0.078651                         0.067475
# 1                          0.529145                         0.599859
# 2                          0.079030                         0.084720
# 3                          0.101521                         0.093638
# 4                          0.093832                         0.059395
# ..                              ...                              ...
# 77                         0.217104                         0.278190
# 78                         0.399367                         0.344505
# 79                         0.039980                         0.036858
# 80                         0.043134                         0.041546
# 81                         0.637089                         0.668059
#
#     OS_2year_censored_pred_model_49  OS_2year_censored_pred_model_5  \
# 0                          0.049408                        0.036594
# 1                          0.528259                        0.548403
# 2                          0.120473                        0.105649
# 3                          0.108425                        0.071430
# 4                          0.050136                        0.081302
# ..                              ...                             ...
# 77                         0.293208                        0.245213
# 78                         0.337731                        0.392718
# 79                         0.072182                        0.072634
# 80                         0.031550                        0.053874
# 81                         0.662996                        0.671311
#
#     OS_2year_censored_pred_model_50  OS_2year_censored_pred_model_6  \
# 0                          0.043363                        0.040610
# 1                          0.569729                        0.505718
# 2                          0.089449                        0.068653
# 3                          0.131874                        0.087463
# 4                          0.045287                        0.063182
# ..                              ...                             ...
# 77                         0.277689                        0.252699
# 78                         0.407686                        0.302757
# 79                         0.035109                        0.060971
# 80                         0.052260                        0.026710
# 81                         0.659501                        0.649766
#
#     OS_2year_censored_pred_model_7  OS_2year_censored_pred_model_8  \
# 0                         0.064725                        0.100533
# 1                         0.543604                        0.526629
# 2                         0.064565                        0.074061
# 3                         0.146820                        0.079030
# 4                         0.066005                        0.059009
# ..                             ...                             ...
# 77                        0.263698                        0.272046
# 78                        0.273776                        0.376149
# 79                        0.061641                        0.040782
# 80                        0.038107                        0.052036
# 81                        0.632785                        0.668815
#
#     OS_2year_censored_pred_model_9
# 0                         0.088206
# 1                         0.519431
# 2                         0.104501
# 3                         0.082407
# 4                         0.051693
# ..                             ...
# 77                        0.207063
# 78                        0.268789
# 79                        0.034456
# 80                        0.029292
# 81                        0.690808
#
# [82 rows x 52 columns]

# %%
import matplotlib.pyplot as plt

# Select columns with '_pred_' in their name
pred_cols = [col for col in df.columns if '_pred_' in col]

# Select first few rows (e.g., first 10)
df = df.sort_values(by=pred_cols[0], ascending=False)
subset = df[pred_cols].head(3)

# Plot each row as a separate histogram with a different color
colors = plt.cm.tab10.colors  # Use tab10 colormap for up to 10 distinct colors

plt.figure(figsize=(10, 6))
for idx, row in subset.iterrows():
    plt.hist(row.values, bins=20, alpha=0.5, color=colors[idx % len(colors)], label=f'Row {idx}')

plt.title("Spread of Prediction Values (First 10 Rows)")
plt.xlabel("Prediction Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Select columns with '_pred_' in their name
pred_cols = [col for col in df.columns if '_pred_' in col]

# Select first few rows (e.g., first 10)
df = df.sort_values(by=pred_cols[0], ascending=False)
subset = df[pred_cols].head(3)

# Plot each row as a separate histogram with a different color
colors = plt.cm.tab10.colors  # Use tab10 colormap for up to 10 distinct colors

plt.figure(figsize=(10, 6))
for idx, row in subset.iterrows():
    plt.hist(row.values, bins=20, alpha=0.5, color=colors[idx % len(colors)], label=f'Row {idx}')

plt.title("Spread of Prediction Values (First 10 Rows)")
plt.xlabel("Prediction Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()
