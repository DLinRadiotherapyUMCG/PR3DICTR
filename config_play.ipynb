# %%
# %load_ext autoreload
# %autoreload 2

# import yaml
from ruamel.yaml import YAML
from ruamel.yaml.comments import CommentedSeq
from src.config_presets.tools.get_config import get_config
from src.config_presets.tools.save_config import save_config, lists_to_flow_style

# %%
CONFIG_NAME = 'Daniel/Uncertainty_main'
config = get_config(CONFIG_NAME)

# %%
from ruamel.yaml import YAML

yaml = YAML()
# yaml.indent(mapping=2, sequence=2, offset=2)
yaml.width = 80
#yaml.preserve_quotes = True   # optional, keeps original quoting

config_new = lists_to_flow_style(config)

with open("new_config_RUMAMEL_new.yaml", "w") as f:
    yaml.dump(config_new, f)

# %%
with open("new_config_2.yaml", "w") as f:
    yaml.dump(config, f, sort_keys=True)
