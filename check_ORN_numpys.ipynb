# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df_ORN = pd.read_csv(r"//zkh/appdata/RTDicom/Projectline_HNC_modelling/Users/Daniel MacRae/6. Unbalanced dataset/Data/ORN_Sanne_v4_w_DVH_with_splits.csv", sep=';')
df_ORN['UMCGNR'] = df_ORN['UMCGNR'].astype(str).str.zfill(7)
IDs = df_ORN['UMCGNR'].tolist()
len(IDs)
# Out:
# 1154

# %%
IDs
# Out:
# ['0005680',
#  '0006221',
#  '0016369',
#  '0020715',
#  '0021879',
#  '0049714',
#  '0052277',
#  '0059896',
#  '0064747',
#  '0066593',
#  '0070426',
#  '0079378',
#  '0079595',
#  '0092560',
#  '0099759',
#  '0103413',
#  '0113306',
#  '0143253',
#  '0144287',
#  '0153056',
#  '0156646',
#  '0163115',
#  '0163517',
#  '0180652',
#  '0182246',
#  '0185080',
#  '0191693',
#  '0194775',
#  '0197871',
#  '0199636',
#  '0201213',
#  '0213240',
#  '0253090',
#  '0253531',
#  '0260377',
#  '0262827',
#  '0263641',
#  '0263964',
#  '0263980',
#  '0267385',
#  '0276627',
#  '0287554',
#  '0292263',
#  '0298536',
#  '0300780',
#  '0301435',
#  '0303865',
#  '0308052',
#  '0314815',
#  '0315925',
#  '0321403',
#  '0330684',
#  '0334826',
#  '0339740',
#  '0340294',
#  '0341202',
#  '0343548',
#  '0345451',
#  '0353501',
#  '0353682',
#  '0359912',
#  '0361074',
#  '0385303',
#  '0400509',
#  '0401445',
#  '0407063',
#  '0407737',
#  '0412104',
#  '0433231',
#  '0455447',
#  '0457562',
# ...

# %%
ORN_dataset_dir = r"\\zkh\appdata\RTDicom\Projectline_HNC_modelling\Users\Daniel MacRae\6. Unbalanced dataset\Data\dataset_full_ORN"
numpy_list = os.listdir(ORN_dataset_dir)
numpy_list

ORN_dataset_two_dir = r"\\zkh\appdata\RTDicom\Projectline_HNC_modelling\Users\Daniel MacRae\6. Unbalanced dataset\Data\ORN_data_preprocessed\dataset_full"
numpy_two_list = os.listdir(ORN_dataset_two_dir)
numpy_two_list
# Out:
# ['0006221',
#  '0016369',
#  '0099759',
#  '0144287',
#  '0180652',
#  '0199636',
#  '0201213',
#  '0300780',
#  '0301435',
#  '0308052',
#  '0341202',
#  '0353501',
#  '0353682',
#  '0401445',
#  '0407737',
#  '0433231',
#  '0457562',
#  '0474609',
#  '0656980',
#  '0666735',
#  '0974117',
#  '1178564',
#  '1216784',
#  '1219980',
#  '1394254',
#  '1399813',
#  '1426266',
#  '1591144',
#  '1698003',
#  '1920363',
#  '2016610',
#  '2058876',
#  '2075963',
#  '2335507',
#  '2345065',
#  '2347909',
#  '2372322',
#  '2471238',
#  '2471873',
#  '2797629',
#  '2855871',
#  '2910746',
#  '3125931',
#  '3215310',
#  '3305243',
#  '3448582',
#  '3556015',
#  '3632296',
#  '3724953',
#  '3845743',
#  '3905805',
#  '3986938',
#  '4023673',
#  '4080509',
#  '4188222',
#  '4344642',
#  '4491923',
#  '4547462',
#  '4559813',
#  '4579055',
#  '4749435',
#  '4766497',
#  '4799668',
#  '4821509',
#  '4827865',
#  '4897316',
#  '4985462',
#  '4997872',
#  '5004388',
#  '5016704',
#  '5114569',
# ...

# %%
all_in_numpy_list = all(str(id_) in numpy_list or str(id_) in numpy_two_list for id_ in IDs)
print("All IDs are in numpy_list:", all_in_numpy_list)
# Out:
# All IDs are in numpy_list: True

# %%
patient_dir = "/home/macraedc/data/dataset_full_2mm_anonymized/10125"
patient_dir = os.path.join(r"\\zkh\appdata\RTDicom\Projectline_HNC_modelling\Users\Daniel MacRae\6. Unbalanced dataset\Data\dataset_full_only_mandible", "0006221")
CT = np.load(os.path.join(patient_dir, "ct.npy"))[0]
RTDOSE = np.load(os.path.join(patient_dir, "rtdose.npy"))[0]
RTSTRUCT = np.load(os.path.join(patient_dir, "segmentation_map.npy"))[0]

# %%
CT.shape
# Out:
# (64, 160, 160)

# %%
plt.imshow(RTDOSE[20], cmap='viridis')
plt.colorbar(label='Dose')
plt.show()
