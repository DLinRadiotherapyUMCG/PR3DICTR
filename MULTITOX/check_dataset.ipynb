# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_excel(r"\\zkh\appdata\RTDicom\Projectline_HNC_modelling\PRI2MA\HNC_complete_dataset_excel\PRIMA_2025_dataset.xlsx")

# %%
df.Xerostomia_M06.value_counts()
# Out:
# Xerostomia_M06
# Een beetje       472
# Nogal            372
# Helemaal niet    266
# Heel erg         157
# Name: count, dtype: int64

# %%
df.Xerostomia_M06.value_counts(normalize=True)
# Out:
# Xerostomia_M06
# Een beetje       0.372534
# Nogal            0.293607
# Helemaal niet    0.209945
# Heel erg         0.123915
# Name: proportion, dtype: float64
