# %%
\\zkh\appdata\RTDicom\Projectline_HNC_modelling\Users\Daniel MacRae\1. MultiTox_HNC\Feb_2025_results\Trial_32\KFold1
['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Sticky_W01_Nogal_Heel_erg', 'Sticky_W01_Een_beetje'] 
['intercept', 'Parotid_log_of_mean', 'Oral_Cavity_sqrt_of_mean', 'Leeftijd'] [-5.994653424334665, 0.1327494805041005, 0.3410706824721612, 4.215428214299025]
['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Xerostomia_W01_Nogal_Heel_erg', 'Xerostomia_W01_Een_beetje', 'Xerostomia_W01_Helemaal_niet'] [-1.3586108659448954, 0.020979867706486063, 0.10454550888235185, 0.34078846666116536, -0.3963579152545661, -1.30304141734258]
\\zkh\appdata\RTDicom\Projectline_HNC_modelling\Users\Daniel MacRae\1. MultiTox_HNC\Feb_2025_results\Trial_32\KFold2
['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Sticky_W01_Nogal_Heel_erg', 'Sticky_W01_Een_beetje'] [-2.262959299665024, 0.013730506890448052, 0.061623282399930035, 1.4789506322616242, 0.7602488015341676]
['intercept', 'Parotid_log_of_mean', 'Oral_Cavity_sqrt_of_mean', 'Leeftijd'] [-5.642259487916784, 0.08753078897421619, 0.3288610825802054, 3.9517811172492845]
['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Xerostomia_W01_Nogal_Heel_erg', 'Xerostomia_W01_Een_beetje', 'Xerostomia_W01_Helemaal_niet'] [-1.4045858807633618, 0.020882649968587075, 0.106940056209371, 0.2588379987445036, -0.3826013569901218, -1.2808225225058512]
\\zkh\appdata\RTDicom\Projectline_HNC_modelling\Users\Daniel MacRae\1. MultiTox_HNC\Feb_2025_results\Trial_32\KFold3
['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Sticky_W01_Nogal_Heel_erg', 'Sticky_W01_Een_beetje'] [-1.962629283990218, 0.01020564941097653, 0.04761579193114089, 1.4210123469314515, 0.8234177963526885]
['intercept', 'Parotid_log_of_mean', 'Oral_Cavity_sqrt_of_mean', 'Leeftijd'] [-5.209785943063863, 0.014110370904431185, 0.36766145483842283, 3.2513515637524573]
['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Xerostomia_W01_Nogal_Heel_erg', 'Xerostomia_W01_Een_beetje', 'Xerostomia_W01_Helemaal_niet'] [-1.4002568006675098, 0.02129376096512818, 0.10654469711320391, 0.2332106506513586, -0.32787425000652354, -1.3055932013002185]
\\zkh\appdata\RTDicom\Projectline_HNC_modelling\Users\Daniel MacRae\1. MultiTox_HNC\Feb_2025_results\Trial_32\KFold4
['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Sticky_W01_Nogal_Heel_erg', 'Sticky_W01_Een_beetje'] [-2.151419992712328, 0.011485857384278687, 0.05310869955759878, 1.86036902476454, 0.8675297355840953]
['intercept', 'Parotid_log_of_mean', 'Oral_Cavity_sqrt_of_mean', 'Leeftijd'] [-5.935936202069775, 0.09178305572298343, 0.3702217771200515, 3.96974637042031]
    [-5.971097372309848, 0.11171242726376965, 0.410117513180291, 3.577117495651575]
]

Xerostomia = [
    [-2.4795669402601686, 0.02113826280461968, 0.10321768526526263, 2.8498354954886045, 0.7289954282206375],
    [-2.4677705597010178, 0.020526594839806064, 0.1058359638700763, 1.1251889068619607, 0.7082230611176347],
    [-2.486172995173002, 0.02112594241047404, 0.10529832833703404, 1.1628561759313656, 0.7770592115455042],
    [-2.527428354182046, 0.021029018500513617, 0.10373772907169106, 1.3470574511277666, 0.8111784287988582],
    [-2.5661749513357828, 0.02252898514553477, 0.10917465457528422, 0.5704494210745134, 0.5936887437633145]
]

# %%
import numpy as np


aspiration_means = np.mean(Aspiration, axis=0)
aspiration_features = ['intercept', 'PCM_Med_meandose', 'Aspiration_W01_Een_beetje', 'Aspiration_W01_Nogal_Heel_erg']
for i, feature in enumerate(aspiration_features):
    print(f"{feature}: {aspiration_means[i]:.4f}")
# Out:
# intercept: -3.9003
# PCM_Med_meandose: 0.0183
# Aspiration_W01_Een_beetje: 1.4086
# Aspiration_W01_Nogal_Heel_erg: 2.0869

# %%
dysphagia_means = np.mean(Dysphagia, axis=0)
dysphagia_features = ['intercept', 'OralCavity_Ext_meandose', 'PCM_Sup_meandose', 'Loctum2_Larynx', 'Dysphagia_W01_Grade2', 'Loctum2_Pharynx', 'Dysphagia_W01_Grade3_4', 'PCM_Inf_meandose', 'PCM_Med_meandose']
for i, feature in enumerate(dysphagia_features):
    print(f"{feature}: {dysphagia_means[i]:.4f}")
# Out:
# intercept: -3.0176
# OralCavity_Ext_meandose: 0.0203
# PCM_Sup_meandose: 0.0165
# Loctum2_Larynx: -1.2493
# Dysphagia_W01_Grade2: 1.0003
# Loctum2_Pharynx: -0.7894
# Dysphagia_W01_Grade3_4: 1.1852
# PCM_Inf_meandose: 0.0094
# PCM_Med_meandose: 0.0109

# %%
sticky_means = np.mean(Sticky, axis=0)
sticky_features = ['intercept', 'Submandibular_meandose', 'Parotid_sum_of_sqrts', 'Sticky_W01_Nogal_Heel_erg', 'Sticky_W01_Een_beetje']
for i, feature in enumerate(sticky_features):
    print(f"{feature}: {sticky_means[i]:.4f}")
# Out:
# intercept: -2.1110
# Submandibular_meandose: 0.0120
# Parotid_sum_of_sqrts: 0.0523
# Sticky_W01_Nogal_Heel_erg: 1.5565
# Sticky_W01_Een_beetje: 0.8034

# %%
taste_means = np.mean(Taste, axis=0)
taste_features = ['intercept', 'Parotid_log_of_mean', 'Oral_Cavity_sqrt_of_mean', 'Leeftijd']
for i, feature in enumerate(taste_features):
    print(f"{feature}: {taste_means[i]:.4f}")
# Out:
# intercept: -5.7507
# Parotid_log_of_mean: 0.0876
# Oral_Cavity_sqrt_of_mean: 0.3636
# Leeftijd: 3.7931

# %%
xerostomia_means = np.mean(Xerostomia, axis=0)
xerostomia_features = ['intercept', 'Submandibular_meandose', 'Parotid_sum_sqrt', 'Xerostomia_W01_Heel_erg', 'Xerostomia_W01_Een_beetje'] 
for i, feature in enumerate(xerostomia_features):
    print(f"{feature}: {xerostomia_means[i]:.4f}")
# Out:
# intercept: -2.5054
# Submandibular_meandose: 0.0213
# Parotid_sum_sqrt: 0.1055
# Xerostomia_W01_Heel_erg: 1.4111
# Xerostomia_W01_Een_beetje: 0.7238
