# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path
path_src = os.getcwd()
sys.path.insert(1, path_src)

import pandas as pd
import numpy as np

# import two parent directiories upwards (e.g. to reach the `src` directory))
sys.path.insert(1, os.path.join(sys.path[0], '..', '..'))


from src.config_presets.tools.get_config import get_config
from src.utils.set_random_seed import set_random_seed
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config = get_config('Multi_time')

# Disable randomness
set_random_seed(config['general']['seed'])
# Out:
# src/Config_presets/Base_config.yaml
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 config = get_config('Multi_time')
#       3 # Disable randomness
#       4 set_random_seed(config['general']['seed'])
#
# File c:\Users\S.P.M. de Vette\OneDrive - UMCG\Desktop\pred_RT\notebooks\Daniel_testing\..\..\src\config_presets\tools\get_config.py:37, in get_config(name, name_base)
#      31 """
#      32 Constructs config as used throughout the main file
#      33 """
#      36 # Load
# ---> 37 base_config = load_config(name_base)
#      38 experiment_config = load_config(name)
#      40 # Initiate the to be returned config file
#
# File c:\Users\S.P.M. de Vette\OneDrive - UMCG\Desktop\pred_RT\notebooks\Daniel_testing\..\..\src\config_presets\tools\get_config.py:21, in load_config(name)
#      19 # Check if the config file exists
#      20 if not os.path.exists(config_path):
# ---> 21     raise ValueError('Config file not found. Please check the toxicity_configs folder.')
#      23 # Load the config file
#      24 with open(config_path, 'r') as f:
#
# ValueError: Config file not found. Please check the toxicity_configs folder.

# %% [markdown]
# # Notebook to test the dataloading and dataloader speeds
