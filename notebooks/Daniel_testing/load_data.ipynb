# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path
path_src = os.getcwd()
sys.path.insert(1, path_src)

import pandas as pd
import numpy as np

# import two parent directiories upwards (e.g. to reach the `src` directory))
sys.path.insert(1, os.path.join(sys.path[0], '..', '..'))


from src.config_presets.tools.get_config import get_config
from src.utils.set_random_seed import set_random_seed
# Out:
# C:\Users\S.P.M. de Vette\AppData\Local\Temp\ipykernel_18588\1522533175.py:10: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
config = get_config('Multi_time')

# Disable randomness
set_random_seed(config['general']['seed'])

# %% [markdown]
# # Notebook to test the dataloading and dataloader speeds
