# %%
# %load_ext autoreload
# %autoreload 2

# Global libraries
import os
import torch
from torch.utils.data import DataLoader
from collections import defaultdict
from torchviz import make_dot 
from PIL import ImageFont
from torchinfo import summary

# Local libraries enivironment loading
import sys
from pathlib import Path
path_Project = Path(os.getcwd()).parent.parent
path_Git = path_Project.parent

def IncludeDirectory(path, index = 0, indexStop = -1):
    if(os.path.exists(path) and (index <= indexStop or indexStop == -1)):
        print(path)
        sys.path.append(path)
        children = os.listdir(path)
        for i in range(len(children)):
            pathChild = os.path.join(path,children[i])
            if(os.path.isdir(pathChild)):
                IncludeDirectory(pathChild, index + 1, indexStop)

# Activate the function
IncludeDirectory(path_Git,0,1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\Users\r.van.der.wal\Documents\GitHub
# c:\Users\r.van.der.wal\Documents\GitHub\pred_RT

# %%
# Local libraries
from src.constants import DEVICE
from src.models.tools.get_multi_model import get_classification_model
from src.config_presets.tools.get_config import get_config
from src.dataset.load_dataset import load_dataset_total
from src.training.train_multi import move_batch_to_device, validate, get_output_results
from src.utils.loss_func.get_loss_function import get_loss_function
from src.visualization.Confusion_matrix import confusion_matrix_multi

# %%
# Install the following
#   - App:          graphviz
#   - Python Lib:   pip install graphviz
#   - Python Lib:   pip install torchviz

# Also set graphviz location to PATH
if(False):
    os.environ["PATH"] += os.pathsep + r"C:\Program Files\Graphviz\bin"

# %%
# Load the configurations for the model
config = get_config('DETOXLung_config', pathGiven = str(path_Project))
config['general']['trialNumber'] = "Notebook_Test"
config['paths']['results'] = r"C:/Users/r.van.der.wal/Documents/"
# Load example dataset for input and output expectations of model
dataset, metadata = load_dataset_total(config)

# Get model
model = get_classification_model(config,metadata)
model.to(device=DEVICE)
# Out:
# c:\Users\r.van.der.wal\Documents\GitHub\pred_RT\src\config_presets\Base_config.yaml
# c:\Users\r.van.der.wal\Documents\GitHub\pred_RT\src\config_presets\DETOXLung_config.yaml
# Patient collection --> Train: 572, Validation: 156
# Patient collection --> Test: 308
# c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# MultiTox_Classifier(
#   (encoder): DCNN_Pooling(
#     (first_conv_blocks): ModuleList()
#     (conv_blocks): ModuleList(
#       (0): small_conv_block(
#         (pad): conv3d_padding_same()
#         (conv1): Conv3d(3, 8, kernel_size=(7, 7, 7), stride=(1, 1, 1))
#         (activation1): LeakyReLU(negative_slope=0.1)
#         (norm1): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (pool): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#       (1): small_conv_block(
#         (pad): conv3d_padding_same()
#         (conv1): Conv3d(8, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#         (activation1): LeakyReLU(negative_slope=0.1)
#         (norm1): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (pool): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#       (2): small_conv_block(
#         (pad): conv3d_padding_same()
#         (conv1): Conv3d(8, 16, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#         (activation1): LeakyReLU(negative_slope=0.1)
#         (norm1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (pool): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#       (3): small_conv_block(
#         (pad): conv3d_padding_same()
#         (conv1): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#         (activation1): LeakyReLU(negative_slope=0.1)
#         (norm1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (pool): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#       (4): small_conv_block(
#         (pad): conv3d_padding_same()
#         (conv1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#         (activation1): LeakyReLU(negative_slope=0.1)
#         (norm1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (pool): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (output_head): MultiToxOutputHead(
#     (clinical_variables_shared_fc_layers): ModuleList(
#       (0): Dropout(p=0.06087816611628816, inplace=False)
#       (1): Linear(in_features=11, out_features=32, bias=True)
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): Dropout(p=0.06087816611628816, inplace=False)
#       (4): Linear(in_features=32, out_features=16, bias=True)
#       (5): LeakyReLU(negative_slope=0.1)
#     )
#     (shared_fc_layers): ModuleList(
#       (0): Dropout(p=0.06087816611628816, inplace=False)
#       (1): Linear(in_features=3216, out_features=16, bias=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (endpoint_heads): ModuleDict(
#       (RP_OneYear): ModuleList(
#         (0): Dropout(p=0.06087816611628816, inplace=False)
#         (1): Linear(in_features=16, out_features=64, bias=True)
#         (2): LeakyReLU(negative_slope=0.1)
#         (3): Linear(in_features=64, out_features=1, bias=True)
#       )
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
# )

# %%
outputs = None
train_loader = DataLoader(dataset[0][0], batch_size=config['training']['batch_size'], shuffle=True)
val_loader = DataLoader(dataset[1][0], batch_size=config['training']['batch_size'], shuffle=True)
for i, batch in enumerate(train_loader):
    inputs, clinical_features, targets = move_batch_to_device(batch, DEVICE)
    # Make predictions
    outputs = model(x=inputs, features=clinical_features)
    break

# %%
len(dataset[1][0])
# Out:
# 146

# %%
loss_function = get_loss_function(config)
val_loss, auc_val = validate(loss_function, model, val_loader, config)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 2
#       1 loss_function = get_loss_function(config)
# ----> 2 val_loss, auc_val = validate(loss_function, model, val_loader, config)
#
# File c:\Users\r.van.der.wal\Documents\GitHub\pred_RT\src\training\train_multi.py:193, in validate(loss_function, model, val_loader, config)
#     189     targets_tot[label] = []
#     192 with torch.no_grad():
# --> 193     for i, batch in enumerate(val_loader):
#     194         logging.debug(f'Validation batch {i}')
#     195         inputs, clinical_features, targets = move_batch_to_device(batch, DEVICE)
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\r.van.der.wal\Documents\GitHub\pred_RT\src\dataset\ToxDataset.py:214, in ToxDataset.__getitem__(self, idx)
#     211     segmentation_map = np.expand_dims(segmentation_map,axis = 0)
#     213 # Stack the images vertically
# --> 214 image_stack = np.vstack((ct, dose, segmentation_map), dtype=np.float32)
#     216 # Preprocess the image_stack
#     217 image_stack = preprocess_image_stack(image_stack, self.config).astype(np.float32)
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\numpy\core\shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:

# %%
out_tot, targets_tot = get_output_results(model, val_loader, config)
# Out:
# c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\_tensor.py:1443: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   ret = func(*args, **kwargs)

# %%
# Create the confusion matrix
fileName = "test"
confusion_matrix_multi(fileName, out_tot, targets_tot,config)

# %%
clinicalFeatures = config['columns']['clinical_features']
inputShapeGiven = [(8,3,180,135,170),(8,18)]
print(inputShapeGiven)
summary(model,input_size= inputShapeGiven,device="cuda")
# Out:
# [(8, 3, 180, 135, 170), (8, 18)]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torchinfo\torchinfo.py:295, in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     294 if isinstance(x, (list, tuple)):
# --> 295     _ = model(*x, **kwargs)
#     296 elif isinstance(x, dict):
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\module.py:1582, in Module._call_impl(self, *args, **kwargs)
#    1580     args = bw_hook.setup_input_hook(args)
# -> 1582 result = forward_call(*args, **kwargs)
#    1583 if _global_forward_hooks or self._forward_hooks:
#
# File c:\Users\r.van.der.wal\Documents\GitHub\pred_RT\src\models\tools\get_multi_model.py:35, in MultiTox_Classifier.forward(self, x, features, vectorize)
#      34 # MLP
# ---> 35 x_dict = self.forward_linear_layers(x, features, vectorize=vectorize)
#      37 return x_dict
#
# File c:\Users\r.van.der.wal\Documents\GitHub\pred_RT\src\models\tools\get_multi_model.py:62, in MultiTox_Classifier.forward_linear_layers(self, x, features, vectorize)
#      58 """
#      59 Does a forward pass of only the linear layers (the decision layers)
#      60 Includes the entire output head (clinical, shared and non-shared layers)
#      61 """
# ---> 62 x_dict = self.output_head(x, features, vectorize=vectorize)
#      64 return x_dict
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\module.py:1582, in Module._call_impl(self, *args, **kwargs)
#    1580     args = bw_hook.setup_input_hook(args)
# -> 1582 result = forward_call(*args, **kwargs)
#    1583 if _global_forward_hooks or self._forward_hooks:
#
# File c:\Users\r.van.der.wal\Documents\GitHub\pred_RT\src\models\linear_layers.py:73, in MultiToxOutputHead.forward(self, x, features, vectorize)
#      72     for layer in self.clinical_variables_shared_fc_layers:
# ---> 73         features = layer(features)
#      74        # print("features", features.shape)
#      75
#      76 # Linear layers (SHARED)
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\module.py:1582, in Module._call_impl(self, *args, **kwargs)
#    1580     args = bw_hook.setup_input_hook(args)
# -> 1582 result = forward_call(*args, **kwargs)
#    1583 if _global_forward_hooks or self._forward_hooks:
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (8x18 and 11x32)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[41], line 4
#       2 inputShapeGiven = [(8,3,180,135,170),(8,18)]
#       3 print(inputShapeGiven)
# ----> 4 summary(model,input_size= inputShapeGiven,device="cuda")
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torchinfo\torchinfo.py:223, in summary(model, input_size, input_data, batch_dim, cache_forward_pass, col_names, col_width, depth, device, dtypes, mode, row_settings, verbose, **kwargs)
#     216 validate_user_params(
#     217     input_data, input_size, columns, col_width, device, dtypes, verbose
#     218 )
#     220 x, correct_input_size = process_input(
#     221     input_data, input_size, batch_dim, device, dtypes
#     222 )
# --> 223 summary_list = forward_pass(
#     224     model, x, batch_dim, cache_forward_pass, device, model_mode, **kwargs
#     225 )
#     226 formatting = FormattingOptions(depth, verbose, columns, col_width, rows)
#     227 results = ModelStatistics(
#     228     summary_list, correct_input_size, get_total_memory_used(x), formatting
#     229 )
#
# File c:\Users\r.van.der.wal\.conda\envs\test-env\Lib\site-packages\torchinfo\torchinfo.py:304, in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     302 except Exception as e:
#     303     executed_layers = [layer for layer in summary_list if layer.executed]
# --> 304     raise RuntimeError(
#     305         "Failed to run torchinfo. See above stack traces for more details. "
#     306         f"Executed layers up to: {executed_layers}"
#     307     ) from e
#     308 finally:
#     309     if hooks:
#
# RuntimeError: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: [DCNN_Pooling: 1, small_conv_block: 3, conv3d_padding_same: 4, Conv3d: 4, BatchNorm3d: 4, MaxPool3d: 4, LeakyReLU: 4, small_conv_block: 3, conv3d_padding_same: 4, Conv3d: 4, BatchNorm3d: 4, MaxPool3d: 4, LeakyReLU: 4, small_conv_block: 3, conv3d_padding_same: 4, Conv3d: 4, BatchNorm3d: 4, MaxPool3d: 4, LeakyReLU: 4, small_conv_block: 3, conv3d_padding_same: 4, Conv3d: 4, BatchNorm3d: 4, MaxPool3d: 4, LeakyReLU: 4, small_conv_block: 3, conv3d_padding_same: 4, Conv3d: 4, BatchNorm3d: 4, MaxPool3d: 4, LeakyReLU: 4, Flatten: 1, Dropout: 3]

# %%
# Create the flowdiagram of the model ()
make_dot(outputs['RP_OneYear'].mean(),params=dict(model.named_parameters()))
