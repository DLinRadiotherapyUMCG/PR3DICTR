# %%
import pandas as pd

df = pd.read_csv('C:/Users/S.P.M. de Vette/OneDrive - UMCG/Documents/DL_NTCP_Multitox/datasets/MT_dataset/stratified_sampling_test_542.csv', sep=';')
# Out:
# C:\Users\S.P.M. de Vette\AppData\Local\Temp\ipykernel_14744\692827053.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
labels = ["Aspiration_M06", "Dysphagia_M06", "Sticky_M06", "Taste_M06", "Xerostomia_M06" ]

for label in labels:
    print(label)
    print(df[label].value_counts(normalize=True))
    print('')
# Out:
# Aspiration_M06
# Aspiration_M06
#  0.0    0.822018
# -1.0    0.106422
#  1.0    0.071560
# Name: proportion, dtype: float64
#
# Dysphagia_M06
# Dysphagia_M06
#  0.0    0.728440
#  1.0    0.236697
# -1.0    0.034862
# Name: proportion, dtype: float64
#
# Sticky_M06
# Sticky_M06
#  0.0    0.604587
#  1.0    0.294495
# -1.0    0.100917
# Name: proportion, dtype: float64
#
# Taste_M06
# Taste_M06
#  0.0    0.658716
#  1.0    0.233028
# -1.0    0.108257
# Name: proportion, dtype: float64
#
# Xerostomia_M06
# Xerostomia_M06
#  0.0    0.511009
#  1.0    0.391743
# -1.0    0.097248
# Name: proportion, dtype: float64
