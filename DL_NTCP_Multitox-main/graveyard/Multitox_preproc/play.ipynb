# %%
import os
import numpy as np


save_root_dir_2 = 'H:/HNC_Data/dicom_processed/'
all_patient_folders = next(os.walk(save_root_dir_2))[1]
all_patient_folders
# Out:
# ['0005680',
#  '0020715',
#  '0021879',
#  '0052277',
#  '0059896',
#  '0064747',
#  '0066593',
#  '0070426',
#  '0079378',
#  '0084356',
#  '0092560',
#  '0103413',
#  '0113306',
#  '0137534',
#  '0143253',
#  '0153056',
#  '0153939',
#  '0156646',
#  '0163115',
#  '0163517',
#  '0170637',
#  '0182246',
#  '0185080',
#  '0191693',
#  '0194349',
#  '0194775',
#  '0197871',
#  '0213240',
#  '0222234',
#  '0249713',
#  '0253090',
#  '0260377',
#  '0262827',
#  '0263641',
#  '0263964',
#  '0263980',
#  '0267385',
#  '0276627',
#  '0287554',
#  '0292263',
#  '0298536',
#  '0303865',
#  '0309877',
#  '0314815',
#  '0315925',
#  '0321403',
#  '0330684',
#  '0334826',
#  '0338902',
#  '0339381',
#  '0339740',
#  '0340294',
#  '0343548',
#  '0345451',
#  '0359912',
#  '0385303',
#  '0400509',
#  '0401057',
#  '0402490',
#  '0407063',
#  '0409363',
#  '0412104',
#  '0453763',
#  '0455447',
#  '0459618',
#  '0484397',
#  '0492526',
#  '0507025',
#  '0508784',
#  '0516456',
#  '0517608',
# ...

# %%
for ID in all_patient_folders:
    pth = os.path.join(save_root_dir_2, ID)
    segmap = np.load(os.path.join(pth, 'segmentation_map.npy'))
    unique_count = len(np.unique(segmap))
    if unique_count != 17:
        print(ID, unique_count)
# Out:
# 0359912 16
# 1299897 15
# 2022769 16
# 2103749 16
# 3573430 15
# 5052615 8

# %%
path = "H:/preprocess_multitox/dataset_full/2067099"

segmap = np.load(os.path.join(path, 'segmentation_map.npy'))[0,:,:,:]
segmap.shape
# Out:
# (100, 100, 100)
