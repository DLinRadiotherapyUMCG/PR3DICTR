# %%
import pandas as pd
import numpy as np
import os

path_to_experiment = r"C:\Users\MacRaeDC\OneDrive - UMCG\Bureaublad\Test_TL_Baseline_Models"
path_to_experiment = "HP_experiments/HP_ViT"
fold_folders = os.listdir(path_to_experiment)

# %%
df_folds = []
for fold_folder in fold_folders:
    folder_path = os.path.join(path_to_experiment, fold_folder)
    print(folder_path)
    predictions_csv = os.path.join(folder_path, "ViT_all_outputs.csv")
    df_fold = pd.read_csv(predictions_csv, delimiter=";")
    df_LR_fold = df_LR_fold[df_LR_fold["Mode"]=="val"]
    df_folds.append(df_fold)

df_LR_folds = []
for fold_folder in fold_folders:
    folder_path = os.path.join(path_to_experiment, fold_folder)
    predictions_csv = os.path.join(folder_path, "lr_all_outputs.csv")
    df_LR_fold = pd.read_csv(predictions_csv, delimiter=";")
    df_LR_fold = df_LR_fold[df_LR_fold["Mode"]=="val"]
    df_LR_folds.append(df_LR_fold)
# Out:
# HP_experiments/HP_ViT\.validate_storage_marker
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 print(folder_path)
#       5 predictions_csv = os.path.join(folder_path, "ViT_all_outputs.csv")
# ----> 6 df_fold = pd.read_csv(predictions_csv, delimiter=";")
#       7 df_LR_fold = df_LR_fold[df_LR_fold["Mode"]=="val"]
#       8 df_folds.append(df_fold)
#
# ...

# %%
df_folds[2][df_folds[2]["PatientID"] == 5938385]

ens_asp_pred = 0

for i in range(len(df_folds)):
    print(df_folds[i][df_folds[i]["PatientID"] == 6579698][["Aspiration_M06_pred", "Aspiration_M06_true"]])
    asp_pred = df_folds[i][df_folds[i]["PatientID"] == 6579698]["Aspiration_M06_pred"].values[0]
    #print(asp_pred/5)
    ens_asp_pred += asp_pred/5

print()
print(ens_asp_pred)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_folds[2][df_folds[2]["PatientID"] == 5938385]
#       3 ens_asp_pred = 0
#       5 for i in range(len(df_folds)):
#
# IndexError: list index out of range

# %%
for df in df_folds:
    print(df["PatientID"].head())
# Out:
# 0    7709085
# 1    7808550
# 2    6579698
# 3     777661
# 4    4798221
# Name: PatientID, dtype: int64
# 0    9977441
# 1    2061972
# 2    1769625
# 3    5068359
# 4    1088251
# Name: PatientID, dtype: int64
# 0    5938385
# 1    2023267
# 2    7954980
# 3    8084312
# 4    1140791
# Name: PatientID, dtype: int64
# 0    1858129
# 1    5699537
# 2    3511140
# 3    6579698
# 4     608167
# Name: PatientID, dtype: int64
# 0    5561878
# 1    2578093
# 2    2024557
# 3    8619056
# 4    1052515
# Name: PatientID, dtype: int64

# %%
for df in df_LR_folds:
    print(df["PatientID"].head())
# Out:
# 872     52277
# 873     66593
# 874     92560
# 875    163517
# 876    213240
# Name: PatientID, dtype: int64
# 872     52277
# 873     66593
# 874     92560
# 875    163517
# 876    213240
# Name: PatientID, dtype: int64
# 872     52277
# 873     66593
# 874     92560
# 875    163517
# 876    213240
# Name: PatientID, dtype: int64
# 872     52277
# 873     66593
# 874     92560
# 875    163517
# 876    213240
# Name: PatientID, dtype: int64
# 872     52277
# 873     66593
# 874     92560
# 875    163517
# 876    213240
# Name: PatientID, dtype: int64
