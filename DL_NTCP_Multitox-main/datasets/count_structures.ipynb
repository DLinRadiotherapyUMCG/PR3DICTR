# %%
import numpy as np
import pandas as pd
import os
# Out:
# C:\Users\MacRaeDC\AppData\Local\Temp\ipykernel_6380\3339900087.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
patient_folder_dir = os.path.join("dataset_dan", "patients")



patient_ID_set = os.listdir(patient_folder_dir)

for ID in patient_ID_set:
    SEGMAP = np.load(os.path.join(patient_folder_dir, ID, "segmentation_map.npy"))[0,:,:,:]
    unique_values = np.unique(SEGMAP)
    count = len(unique_values)
    if count != 17:
        print(ID, count)
# Out:
# 0359912 16
# 5052615 16
# 3573430 15
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#patient_folder_dir = os.path.join("dataset_dan", "patients")

patient_folder_dir = "//zkh/appdata/RTDicom/Projectline_HNC_modelling/PRI2MA/preprocessed/dataset_full"

patient_ID_set = os.listdir(patient_folder_dir)

for ID in patient_ID_set:
    SEGMAP = np.load(os.path.join(patient_folder_dir, ID, "segmentation_map.npy"))[0,:,:,:]
    unique_values = np.unique(SEGMAP)
    count = len(unique_values)
    if count != 17:
        print(ID, count)
# Out:
# 0359912 16
# 2022769 16
# 5052615 8
# 1299897 15
# 2103749 16
# 3573430 15

# %%
patient_folder_dir = "H:/HNC_Data/dicom_processed"

patient_ID_set = os.listdir(patient_folder_dir)

for ID in patient_ID_set:
    SEGMAP = np.load(os.path.join(patient_folder_dir, ID, "segmentation_map.npy"))[:,:,:]
    unique_values = np.unique(SEGMAP)
    count = len(unique_values)
    if count != 17:
        print(ID, count)
# Out:
# 0359912 16
# 1299897 15
# 2022769 16
# 2103749 16
# 3573430 15
# 5052615 8

# %%
patient_folder_dir = "//zkh/appdata/RTDicom/Projectline_HNC_modelling/Users/Suzanne de Vette/7. Dysphagia model/dataset_old_v2/1"

patient_ID_set = os.listdir(patient_folder_dir)

patient_ID_set = ['5052615']
for ID in patient_ID_set:
    SEGMAP = np.load(os.path.join(patient_folder_dir, ID, "segmentation_map.npy"))[:,:,:]
    unique_values = np.unique(SEGMAP)
    count = len(unique_values)
    if count != 17:
        print(ID, count)
# Out:
# 5052615 8

# %%
patient_folder_dir =  "//zkh/appdata/RTDicom/Projectline_HNC_modelling/Users/HungChu/Data/PRI2MA/dataset_new/dataset_full"

patient_ID_set = os.listdir(patient_folder_dir)

for ID in patient_ID_set:
    SEGMAP = np.load(os.path.join(patient_folder_dir, ID, "segmentation_map.npy"))[:,:,:]
    unique_values = np.unique(SEGMAP)
    count = len(unique_values)
    if count != 17:
        print(ID, count)
# Out:
# 0359912 16
# 5052615 8
# 5921911 15
# 3573430 15
